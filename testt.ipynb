# %%
import pandas as pd
import time
import splay1
import bst1
df4=pd.read_csv("unique_tracks.txt",sep="<SEP>",header=None,engine='python')
df6=df4[[2,3]]
df6=df6.dropna()
s1=splay1.Splay()

# %%
for i in range(0,int(df6.size/8)):
    s1.insert(df6.iat[i,0],df6.iat[i,1])

# %%
import random
data =range(1, int(df6.size/8))
import sys
sys.setrecursionlimit(500000)
tm=[]
tm1=[]
# tim=[10000,20000,40000,60000]
for j in range(10):
    dels = random.sample(data, 1000)
    start=time.process_time()
    for i in dels:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            s1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("1",)
    end=time.process_time()
    tm.append(end-start)
    start=time.process_time()
    for i in dels:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            b1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("2",)
    end=time.process_time()
    tm1.append(end-start)
print(tm)
print(tm1)
# start=time.process_time()
# for i in dels:
# #     print(i)
#     start=time.process_time()
#     print(df6.iat[i,0])
#     if df6.iat[i,1]:
#         b1.search(df6.iat[i,0])
#     end=time.process_time()
#     tm1.append(end-start)
#     print("1",)
# print(tm1)
# Out:
# Buraka Som Sistema
# 1
# Emmas Mini
# 1
# Bad Company
# 1
# Jimmy McGriff
# 1
# András Schiff_ Dénas Várjon_ Heinz Holliger & Budapest Festival Orchestra
# 1
# Luis Alberto Spinetta
# 1
# Bob Willis
# 1
# Carmen McRae
# 1
# Higher Ground
# 1
# Evert Taube
# 1
# Erkki Junkkarinen
# 1
# Old Harp Singers of Eastern Tennessee
# 1
# Freddie King
# 1
# Tom Barabas
# 1
# Fous De La Mer
# 1
# The Irish Rovers
# 1
# Aaron Carter
# 1
# Stacy Lattisaw
# 1
# Infectious Organisms
# 1
# The Pribata Idaho
# 1
# Brian Wilson
# 1
# As Cities Burn
# 1
# Hiroshima
# 1
# JennyAnyKind
# 1
# Axwell
# 1
# The Jackie Payne-Steve Edmonson Band
# 1
# Raheem Devaughn
# 1
# Thelonious Monk Quartet
# 1
# Alice In Chains
# 1
# Saeed and Palash
# 1
# Elvis Presley
# 1
# Manuel Vallejo
# 1
# Eric B. & Rakim
# 1
# Manfred Mann's Earth Band
# 1
# Scan X
# 1
# Bob Baldwin
# 1
# The Kills
# 1
# Fats Waller
# 1
# Tom Barabas
# 1
# Amel Larrieux
# 1
# Letta Mbulu
# 1
# Love Affair
# 1
# Frank Bretschneider
# 1
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
size=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]
plt.plot(size,tm)
plt.plot(size,tm1)
plt.show()

# %%
import bst1
b1=bst1.BST()
for i in range(0,int(df6.size/8)):
    b1.insert(df6.iat[i,0],df6.iat[i,1])

# %%
pretty_uneven_accesses10=[]
base = random.randint(0, int(df6.size/8) - 10)
for i in range(1000):
            pretty_uneven_accesses10.append(random.randint(base, base + 10))

# %%
tmm=[]
tmm1=[]
# tim=[10000,20000,40000,60000]
start=time.process_time()
for j in range(10):
    pretty_uneven_accesses10=[]
    base = random.randint(0, int(df6.size/8) - 10)
    for i in range(1000):
            pretty_uneven_accesses10.append(random.randint(base, base + 10))
    for i in pretty_uneven_accesses10:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            s1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("1",)
    end=time.process_time()
    tmm.append(end-start)
start=time.process_time()
for j in range(10):
    pretty_uneven_accesses10=[]
    base = random.randint(0, int(df6.size/8) - 10)
    for i in range(1000):
            pretty_uneven_accesses10.append(random.randint(base, base + 10))
    for i in pretty_uneven_accesses10:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            b1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("2",)
    end=time.process_time()
    tmm1.append(end-start)
print(tmm)
print(tmm1)
# Out:
# Kites
# 1
# Liam Lynch
# 1
# Jay Tee
# 1
# Lydian Sea
# 1
# Dog Fashion Disco_ Acid Bath
# 1
# Jay Tee
# 1
# Jay Tee
# 1
# Big Bang
# 1
# The Out Crowd
# 1
# Liam Lynch
# 1
# Sole & the Skyrider Band
# 1
# Lydian Sea
# 1
# Jay Tee
# 1
# Big Bang
# 1
# Sole & the Skyrider Band
# 1
# Big Bang
# 1
# G Unit feat. 50 Cent
# 1
# Sole & the Skyrider Band
# 1
# Dog Fashion Disco_ Acid Bath
# 1
# Liam Lynch
# 1
# Kites
# 1
# Liam Lynch
# 1
# Jay Tee
# 1
# Liam Lynch
# 1
# Lydian Sea
# 1
# G Unit feat. 50 Cent
# 1
# Dave Grusin
# 1
# G Unit feat. 50 Cent
# 1
# In Praise Of Folly
# 1
# Jay Tee
# 1
# Liam Lynch
# 1
# Kites
# 1
# The Out Crowd
# 1
# G Unit feat. 50 Cent
# 1
# Dog Fashion Disco_ Acid Bath
# 1
# Dave Grusin
# 1
# Lydian Sea
# 1
# Dog Fashion Disco_ Acid Bath
# 1
# Big Bang
# 1
# Dave Grusin
# 1
# Jay Tee
# 1
# Dave Grusin
# 1
# Kites
# 1
# Lydian Sea
# 1
# Dave Grusin
# 1
# In Praise Of Folly
# 1
# Jay Tee
# 1
# Dog Fashion Disco_ Acid Bath
# 1
# Dog Fashion Disco_ Acid Bath
# 1
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
size=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]
plt.plot(size,tmm,label='Splay')
plt.plot(size,tmm1,label='BST')
plt.legend()
plt.show()

# %%
pretty_uneven_accesses4=[]
base = random.randint(0, int(df6.size/8) - 4)
for i in range(1000):
            pretty_uneven_accesses4.append(random.randint(base, base + 4))

# %%
tmm=[]
tmm1=[]
# tim=[10000,20000,40000,60000]
start=time.process_time()
for j in range(10):
    pretty_uneven_accesses4=[]
    base = random.randint(0, int(df6.size/8) - 4)
    for i in range(1000):
            pretty_uneven_accesses4.append(random.randint(base, base + 4))
    for i in pretty_uneven_accesses4:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            s1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("1",)
    end=time.process_time()
    tmm.append(end-start)
start=time.process_time()
for j in range(10):
    pretty_uneven_accesses4=[]
    base = random.randint(0, int(df6.size/8) - 4)
    for i in range(1000):
            pretty_uneven_accesses4.append(random.randint(base, base + 4))
    for i in pretty_uneven_accesses4:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            b1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("2",)
    end=time.process_time()
    tmm1.append(end-start)
print(tmm)
print(tmm1)
# Out:
# 40 Grit
# 1
# Diam's
# 1
# Diam's
# 1
# Gabriela Anders
# 1
# 40 Grit
# 1
# Loquillo Y Los Trogloditas
# 1
# Loquillo Y Los Trogloditas
# 1
# Westside Connection
# 1
# Gabriela Anders
# 1
# Loquillo Y Los Trogloditas
# 1
# Diam's
# 1
# Westside Connection
# 1
# Gabriela Anders
# 1
# Diam's
# 1
# Diam's
# 1
# Loquillo Y Los Trogloditas
# 1
# Loquillo Y Los Trogloditas
# 1
# Loquillo Y Los Trogloditas
# 1
# Loquillo Y Los Trogloditas
# 1
# Gabriela Anders
# 1
# 40 Grit
# 1
# Loquillo Y Los Trogloditas
# 1
# Loquillo Y Los Trogloditas
# 1
# 40 Grit
# 1
# 40 Grit
# 1
# Westside Connection
# 1
# Westside Connection
# 1
# Gabriela Anders
# 1
# 40 Grit
# 1
# Gabriela Anders
# 1
# Loquillo Y Los Trogloditas
# 1
# Westside Connection
# 1
# Westside Connection
# 1
# 40 Grit
# 1
# Diam's
# 1
# Loquillo Y Los Trogloditas
# 1
# 40 Grit
# 1
# Diam's
# 1
# Diam's
# 1
# 40 Grit
# 1
# Westside Connection
# 1
# Loquillo Y Los Trogloditas
# 1
# 40 Grit
# 1
# Gabriela Anders
# 1
# Westside Connection
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
size=[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]
plt.plot(size,tmm,label='Splay')
plt.plot(size,tmm1,label='BST')
plt.legend()
plt.show()

# %%
pretty_uneven_accesses3=[]
base = random.randint(0, int(df6.size/8) - 3)
for i in range(1000):
            pretty_uneven_accesses3.append(random.randint(base, base + 3))

# %%
tmm=[]
tmm1=[]
# tim=[10000,20000,40000,60000]
for j in range(1):
    start=time.process_time()
    for i in pretty_uneven_accesses3:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            s1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("1",)
    end=time.process_time()
    tmm.append(end-start)
    start=time.process_time()
    for i in pretty_uneven_accesses3:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            b1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("2",)
    end=time.process_time()
    tmm1.append(end-start)
print(tmm)
print(tmm1)
# Out:
# The Moffatts
# 1
# Sonora Santanera
# 1
# The Moffatts
# 1
# Sonora Santanera
# 1
# Chimène Badi
# 1
# The Moffatts
# 1
# Chimène Badi
# 1
# The Moffatts
# 1
# The Moffatts
# 1
# Sonora Santanera
# 1
# Chimène Badi
# 1
# The Mick Fleetwood Blues Band
# 1
# The Mick Fleetwood Blues Band
# 1
# Sonora Santanera
# 1
# The Mick Fleetwood Blues Band
# 1
# Chimène Badi
# 1
# The Mick Fleetwood Blues Band
# 1
# Chimène Badi
# 1
# Chimène Badi
# 1
# Chimène Badi
# 1
# The Moffatts
# 1
# The Mick Fleetwood Blues Band
# 1
# The Moffatts
# 1
# The Moffatts
# 1
# Sonora Santanera
# 1
# Chimène Badi
# 1
# The Moffatts
# 1
# Chimène Badi
# 1
# The Mick Fleetwood Blues Band
# 1
# Chimène Badi
# 1
# Sonora Santanera
# 1
# The Moffatts
# 1
# Sonora Santanera
# 1
# The Mick Fleetwood Blues Band
# 1
# Sonora Santanera
# 1
# Chimène Badi
# 1
# The Mick Fleetwood Blues Band
# 1
# Sonora Santanera
# 1
# Sonora Santanera
# 1
# Chimène Badi
# 1
# The Moffatts
# 1
# Sonora Santanera
# 1
# Sonora Santanera
# ...

# %%
even3=[]
a=random.randint(0,int(df6.size/8))
for i in range(334):
    even3.append(a)
a=random.randint(0,int(df6.size/8))
for i in range(334):
    even3.append(a)
a=random.randint(0,int(df6.size/8))
for i in range(334):
    even3.append(a)

# %%
tmm=[]
tmm1=[]
# tim=[10000,20000,40000,60000]
for j in range(1):
    start=time.process_time()
    for i in even3:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            s1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("1",)
    end=time.process_time()
    tmm.append(end-start)
    start=time.process_time()
    for i in even3:
#     print(i)
#         start=time.process_time()
        print(df6.iat[i,0])
        if df6.iat[i,1]:
            b1.search(df6.iat[i,0])
#     end=time.process_time()
#         tm.append(end-start)
        print("2",)
    end=time.process_time()
    tmm1.append(end-start)
print(tmm)
print(tmm1)
# Out:
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# 1
# J.B.O.
# ...
