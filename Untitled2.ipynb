# %%
import bst
import splay
import time

# %%
import test_suite
# Out:
# [10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000, 100000]
# [0.11875, 0.271875, 0.50625, 1.00625, 0.84375, 1.384375, 1.340625, 1.759375, 2.41875, 2.61875]
# [0.421875, 0.896875, 1.6875, 3.028125, 2.7125, 4.80625, 4.5, 5.253125, 6.86875, 8.003125]
# [0.103125, 0.259375, 0.425, 0.86875, 0.565625, 1.365625, 1.1375, 1.325, 1.75, 1.9875]
# [0.021875, 0.028125, 0.05625, 0.071875, 0.065625, 0.103125, 0.121875, 0.125, 0.159375, 0.184375]
# [0.1, 0.20625, 0.43125, 0.74375, 0.603125, 1.315625, 0.978125, 1.465625, 1.728125, 1.825]
# [0.0625, 0.140625, 0.240625, 0.421875, 0.353125, 0.5875, 0.553125, 0.6625, 0.85625, 0.93125]
# [0.125, 0.25625, 0.4375, 0.740625, 0.715625, 1.028125, 1.175, 1.3375, 1.80625, 1.85]
# [0.04375, 0.090625, 0.15, 0.309375, 0.221875, 0.353125, 0.38125, 0.409375, 0.509375, 0.640625]
# [0.00625, 0.0125, 0.009375, 0.015625, 0.0125, 0.01875, 0.009375, 0.021875, 0.028125, 0.009375]
# [0.0125, 0.015625, 0.015625, 0.015625, 0.015625, 0.0125, 0.01875, 0.0125, 0.021875, 0.028125]

# %%
test_suite.avg_uni1()

# %%
test_suite.avg_pretty_uneven1()

# %%
test_suite.avg_pretty_uneven4l()

# %%
test_suite.avg_pretty_uneven101()

# %%
test_suite.avg_del1()

# %%
import test_suite2

# %%
test_suite2.insert_del_same_plot()
# Out:
# [27.089597]
# [27.089597]
# [27.089597]
# [33.412403999999995]
# [33.412403999999995]
# [33.412403999999995]
# [27.089597, 38.729207]
# [27.089597, 38.729207]
# [27.089597, 38.729207]
# [33.412403999999995, 52.49257]
# [33.412403999999995, 52.49257]
# [33.412403999999995, 52.49257]
# [27.089597, 38.729207, 50.92793599999999]
# [27.089597, 38.729207, 50.92793599999999]
# [27.089597, 38.729207, 50.92793599999999]
# [33.412403999999995, 52.49257, 68.44822599999998]
# [33.412403999999995, 52.49257, 68.44822599999998]
# [33.412403999999995, 52.49257, 68.44822599999998]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999, 128.73131699999988]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999, 128.73131699999988]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999, 128.73131699999988]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996, 178.70656800000006]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996, 178.70656800000006]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996, 178.70656800000006]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999, 128.73131699999988, 154.92465200000015]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999, 128.73131699999988, 154.92465200000015]
# [27.089597, 38.729207, 50.92793599999999, 69.13274200000001, 86.89629200000002, 108.18705399999999, 128.73131699999988, 154.92465200000015]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996, 178.70656800000006, 212.90814999999998]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996, 178.70656800000006, 212.90814999999998]
# [33.412403999999995, 52.49257, 68.44822599999998, 94.55257599999999, 118.28507200000001, 150.22196399999996, 178.70656800000006, 212.90814999999998]

# %%
test_suite2.insert_del_opp_plot()
# Out:
# [26.257417000000032]
# [24.421607999999992]
# [26.257417000000032, 38.85353799999996]
# [24.421607999999992, 43.61532999999997]
# [26.257417000000032, 38.85353799999996, 53.56596300000001]
# [24.421607999999992, 43.61532999999997, 61.639993000000004]
# [26.257417000000032, 38.85353799999996, 53.56596300000001, 69.22841199999993]
# [24.421607999999992, 43.61532999999997, 61.639993000000004, 85.61217999999985]
# [26.257417000000032, 38.85353799999996, 53.56596300000001, 69.22841199999993, 89.20140399999991]
# [24.421607999999992, 43.61532999999997, 61.639993000000004, 85.61217999999985, 112.69385299999999]
# [26.257417000000032, 38.85353799999996, 53.56596300000001, 69.22841199999993, 89.20140399999991, 112.11762099999987]
# [24.421607999999992, 43.61532999999997, 61.639993000000004, 85.61217999999985, 112.69385299999999, 144.66096599999992]
# [26.257417000000032, 38.85353799999996, 53.56596300000001, 69.22841199999993, 89.20140399999991, 112.11762099999987, 132.67030099999988]
# [24.421607999999992, 43.61532999999997, 61.639993000000004, 85.61217999999985, 112.69385299999999, 144.66096599999992, 177.41521899999998]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9eae1b9886e1> in <module>
# ----> 1 test_suite2.insert_del_opp_plot()
#
# ~/Documents/APS Project/test_suite2.py in insert_del_opp_plot()
#      84     mmax=10000
#      85     sys.setrecursionlimit(30002)
# ---> 86     maxl,bt,st=insert_del_opp(mmax)
#      87     plt.plot(maxl,bt,'o-',label="BST")
#      88     plt.plot(maxl,st,'x-',label="Splay")
#
# ~/Documents/APS Project/test_suite2.py in insert_del_opp(mmax)
#      55         start=time.process_time()
#      56         for i in range(1,mmax):
# ---> 57             b.insert(i)
#      58         #for i in range(1,mmax):
#      59             # b.search(i)
#
# ~/Documents/APS Project/bst.py in insert(self, key)
#      12     def insert(self, key):
#      13         if self.root:
# ---> 14             self._insert(key, self.root)
#      15         else:
#      16             self.root = Node(key)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ...
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      24         else:
#      25             if node.right:
# ---> 26                 self._insert(key, node.right)
#      27             else:
#      28                 node.right = Node(key, parent=node)
#
# ~/Documents/APS Project/bst.py in _insert(self, key, node)
#      17
#      18     def _insert(self, key, node):
# ---> 19         if key < node.key:
#      20             if node.left:
#      21                 self._insert(key, node.left)
#
# KeyboardInterrupt:
